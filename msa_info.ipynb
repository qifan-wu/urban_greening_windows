# %% [markdown]
# MSA information to put in Materials & Methods

# %%
import constants
import rasterio
import xarray as xr
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt

msa_ds=gpd.read_file(constants.MSA_REGION_FILE)

# %% [markdown]
# ### MSA area information explore

# %%
# Calculate area in square meters
msa_ds['area_km2'] = msa_ds.geometry.area / 1e6

# %%
msa_ds.sort_values(by='area_km2', ascending=False)
# Out:
#                                             NAMELSAD         GEOIDFQ  \
# 251  Riverside-San Bernardino-Ontario, CA Metro Area  310M700US40140
# 24                          Flagstaff, AZ Metro Area  310M700US22380
# 309             Phoenix-Mesa-Chandler, AZ Metro Area  310M700US38060
# 14           Lake Havasu City-Kingman, AZ Metro Area  310M700US29420
# 128                        Boise City, ID Metro Area  310M700US14260
# ..                                               ...             ...
# 273             Racine-Mount Pleasant, WI Metro Area  310M700US39540
# 222                            Kokomo, IN Metro Area  310M700US29020
# 153                           Kenosha, WI Metro Area  310M700US28450
# 289                 Trenton-Princeton, NJ Metro Area  310M700US45940
# 325                       Carson City, NV Metro Area  310M700US16180
#
#            AWATER  GEOID LSAD CBSAFP         ALAND CSAFP  \
# 251  3.392824e+08  40140   M1  40140  7.064819e+10   348
# 24   1.166371e+08  22380   M1  22380  4.821613e+10  None
# 309  8.287165e+07  38060   M1  38060  3.773272e+10   429
# 14   3.333994e+08  29420   M1  29420  3.453002e+10  None
# 128  1.710024e+08  14260   M1  14260  3.047534e+10   147
# ..            ...    ...  ...    ...           ...   ...
# 273  1.190183e+09  39540   M1  39540  8.614578e+08   376
# 222  2.194576e+06  29020   M1  29020  7.590586e+08   294
# 153  1.248872e+09  28450   M1  28450  7.040444e+08   176
# 289  1.133717e+07  45940   M1  45940  5.813954e+08   408
# 325  3.259408e+07  16180   M1  16180  3.743414e+08   456
#
#                                      NAME         region  \
# 251  Riverside-San Bernardino-Ontario, CA           west
# 24                          Flagstaff, AZ      southwest
# 309             Phoenix-Mesa-Chandler, AZ      southwest
# 14           Lake Havasu City-Kingman, AZ      southwest
# 128                        Boise City, ID      northwest
# ..                                    ...            ...
# 273             Racine-Mount Pleasant, WI  upper_midwest
# 222                            Kokomo, IN    ohio_valley
# 153                           Kenosha, WI  upper_midwest
# 289                 Trenton-Princeton, NJ      northeast
# 325                       Carson City, NV           west
#
#                                               geometry      area_km2
# 251  POLYGON ((-1982289.116 1440635.242, -1980782.4...  70986.459750
# 24   POLYGON ((-1540986.297 1584351.486, -1540947.3...  48332.946284
# 309  POLYGON ((-1591144.539 1303026.227, -1589798.4...  37813.500627
# 14   POLYGON ((-1662825.4 1612837.164, -1662579.777...  34863.801460
# 128  POLYGON ((-1671324.249 2501070.058, -1671145.4...  30647.961980
# ..                                                 ...           ...
# 273  POLYGON ((625266.841 2220701.018, 625221.45 22...    881.672727
# 222  POLYGON ((808145.569 1976315.873, 807519.895 1...    761.191432
# 153  POLYGON ((626750.259 2204599.341, 627024.505 2...    720.245002
# 289  POLYGON ((1758945.605 2120925.101, 1759877.622...    592.723335
# 325  POLYGON ((-2033161.325 2051623.531, -2032891.1...    406.895693
#
# [383 rows x 12 columns]

# %%
import matplotlib.pyplot as plt

# Plot histogram of area in square kilometers
plt.figure(figsize=(10, 6))
msa_ds['area_km2'].hist(bins=100, edgecolor='black')

plt.title('Distribution of Area (km²)')
plt.xlabel('Area (km²)')
plt.ylabel('Number of MSAs')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the figure
plt.figure(figsize=(12, 12))

# Use seaborn to create boxplots
sns.boxplot(data=msa_ds, x='region', y='area_km2')

# Customize the plot
plt.xticks(rotation=45)
plt.title('Area Distribution by Region')
plt.xlabel('Region')
plt.ylabel('Area (km²)')
plt.tight_layout()
plt.show()
